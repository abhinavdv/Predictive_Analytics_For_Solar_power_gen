# %%
import pandas as pd

# %%
df=pd.read_csv("merged_final.csv")

# %%
df.head()
# Out:
#    Unnamed: 0         DATE_TIME  PLANT_ID          SCE_KEY  DC_POWER  \
# 0           0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0
# 1           1  15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0
# 2           2  15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0
# 3           3  15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0
# 4           4  15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0
#
#    AC_POWER  DAILY_YIELD  TOTAL_YIELD  PLANT_ID.1       SOURCE_KEY  \
# 0       0.0          0.0    6259559.0     4135001  HmiyD2TTLFNqkNe
# 1       0.0          0.0    6183645.0     4135001  HmiyD2TTLFNqkNe
# 2       0.0          0.0    6987759.0     4135001  HmiyD2TTLFNqkNe
# 3       0.0          0.0    7602960.0     4135001  HmiyD2TTLFNqkNe
# 4       0.0          0.0    7158964.0     4135001  HmiyD2TTLFNqkNe
#
#    AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 0            25.184316           22.857507          0.0
# ...

# %%
df1 = df.loc[df['SCE_KEY']=="1BY6WEcLGh8j5v7"]
df2 = df1.loc[]
# Out:
#   File "<ipython-input-59-5ebd1a4d44b9>", line 2
#     df2 = df1.loc[]
#                   ^
# SyntaxError: invalid syntax

# %%
df1.loc[df["DAILY_YIELD"] > 0]
# Out:
#        Unnamed: 0         DATE_TIME  PLANT_ID          SCE_KEY     DC_POWER  \
# 531           531  15-05-2020 06:15   4135001  1BY6WEcLGh8j5v7   278.000000
# 552           552  15-05-2020 06:30   4135001  1BY6WEcLGh8j5v7   626.571429
# 574           574  15-05-2020 06:45   4135001  1BY6WEcLGh8j5v7  1224.750000
# 596           596  15-05-2020 07:00   4135001  1BY6WEcLGh8j5v7  1734.571429
# 618           618  15-05-2020 07:15   4135001  1BY6WEcLGh8j5v7  1856.375000
# ...           ...               ...       ...              ...          ...
# 68664       68664  17-06-2020 22:45   4135001  1BY6WEcLGh8j5v7     0.000000
# 68686       68686  17-06-2020 23:00   4135001  1BY6WEcLGh8j5v7     0.000000
# 68708       68708  17-06-2020 23:15   4135001  1BY6WEcLGh8j5v7     0.000000
# 68730       68730  17-06-2020 23:30   4135001  1BY6WEcLGh8j5v7     0.000000
# 68752       68752  17-06-2020 23:45   4135001  1BY6WEcLGh8j5v7     0.000000
#
# ...

# %%
df.plot.scatter(x="AMBIENT_TEMPERATURE", y="IRRADIATION",grid=True)

# %%
df.plot.scatter(x="AMBIENT_TEMPERATURE", y="MODULE_TEMPERATURE",grid=True)

# %%
#df["dA"] = df["DAILY_YIELD"].diff(1)

# %%
#df.to_csv('test.csv',index=False)

# %%
df2 = df.loc[df['SCE_KEY'] == "1BY6WEcLGh8j5v7"]
df2.head()
# Out:
#     Unnamed: 0         DATE_TIME  PLANT_ID          SCE_KEY  DC_POWER  \
# 0            0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0
# 21          21  15-05-2020 00:15   4135001  1BY6WEcLGh8j5v7       0.0
# 42          42  15-05-2020 00:30   4135001  1BY6WEcLGh8j5v7       0.0
# 63          63  15-05-2020 00:45   4135001  1BY6WEcLGh8j5v7       0.0
# 84          84  15-05-2020 01:00   4135001  1BY6WEcLGh8j5v7       0.0
#
#     AC_POWER  DAILY_YIELD  TOTAL_YIELD  PLANT_ID.1       SOURCE_KEY  \
# 0        0.0          0.0    6259559.0     4135001  HmiyD2TTLFNqkNe
# 21       0.0          0.0    6259559.0     4135001  HmiyD2TTLFNqkNe
# 42       0.0          0.0    6259559.0     4135001  HmiyD2TTLFNqkNe
# 63       0.0          0.0    6259559.0     4135001  HmiyD2TTLFNqkNe
# 84       0.0          0.0    6259559.0     4135001  HmiyD2TTLFNqkNe
#
#     AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 0             25.184316           22.857507          0.0
# ...

# %%
df2["dA"] = df2["DC_POWER"]+df2["AC_POWER"]
# Out:
# <ipython-input-75-1748e775e65b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["dA"] = df2["DC_POWER"]+df2["AC_POWER"]

# %%
df2["dA"]=df2["dA"].mask(df2["dA"].lt(0),0)
#df2.mask(df2.lt(0)).fillna({'dA':0})
# Out:
# <ipython-input-73-ede695507b94>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["dA"]=df2["dA"].mask(df2["dA"].lt(0),0)

# %%
df2.to_csv('test_sameSCEkey.csv',index=False)

# %%
df2.head()
# Out:
#     Unnamed: 0         DATE_TIME  PLANT_ID          SCE_KEY  DC_POWER  \
# 0            0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0
# 21          21  15-05-2020 00:15   4135001  1BY6WEcLGh8j5v7       0.0
# 42          42  15-05-2020 00:30   4135001  1BY6WEcLGh8j5v7       0.0
# 63          63  15-05-2020 00:45   4135001  1BY6WEcLGh8j5v7       0.0
# 84          84  15-05-2020 01:00   4135001  1BY6WEcLGh8j5v7       0.0
#
#     AC_POWER  DAILY_YIELD  TOTAL_YIELD  PLANT_ID.1       SOURCE_KEY  \
# 0        0.0          0.0    6259559.0     4135001  HmiyD2TTLFNqkNe
# 21       0.0          0.0    6259559.0     4135001  HmiyD2TTLFNqkNe
# 42       0.0          0.0    6259559.0     4135001  HmiyD2TTLFNqkNe
# 63       0.0          0.0    6259559.0     4135001  HmiyD2TTLFNqkNe
# 84       0.0          0.0    6259559.0     4135001  HmiyD2TTLFNqkNe
#
#     AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION   dA
# 0             25.184316           22.857507          0.0  0.0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0         DATE_TIME  PLANT_ID          SCE_KEY  DC_POWER  \
# 0           0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0
# 1           1  15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0
# 2           2  15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0
# 3           3  15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0
# 4           4  15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0
#
#    AC_POWER  DAILY_YIELD  TOTAL_YIELD  PLANT_ID.1       SOURCE_KEY  \
# 0       0.0          0.0    6259559.0     4135001  HmiyD2TTLFNqkNe
# 1       0.0          0.0    6183645.0     4135001  HmiyD2TTLFNqkNe
# 2       0.0          0.0    6987759.0     4135001  HmiyD2TTLFNqkNe
# 3       0.0          0.0    7602960.0     4135001  HmiyD2TTLFNqkNe
# 4       0.0          0.0    7158964.0     4135001  HmiyD2TTLFNqkNe
#
#    AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 0            25.184316           22.857507          0.0
# ...

# %%
df["dA"] = df["DC_POWER"]+df["AC_POWER"]

# %%
df
# Out:
#        Unnamed: 0         DATE_TIME  PLANT_ID          SCE_KEY  DC_POWER  \
# 0               0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0
# 1               1  15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0
# 2               2  15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0
# 3               3  15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0
# 4               4  15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0
# ...           ...               ...       ...              ...       ...
# 68769       68769  17-06-2020 23:45   4135001  uHbuxQJl8lW7ozc       0.0
# 68770       68770  17-06-2020 23:45   4135001  wCURE6d3bPkepu2       0.0
# 68771       68771  17-06-2020 23:45   4135001  z9Y9gH1T5YWrNuG       0.0
# 68772       68772  17-06-2020 23:45   4135001  zBIq5rxdHJRwDNY       0.0
# 68773       68773  17-06-2020 23:45   4135001  zVJPv84UY57bAof       0.0
#
#        AC_POWER  DAILY_YIELD  TOTAL_YIELD  PLANT_ID.1       SOURCE_KEY  \
# ...

# %%
df.to_csv('test_complete.csv',index=False)
